# %%
import pandas as pd

# %%
df = pd.read_csv('teste1.csv')

# %%
df.head(10)
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco         1200401  2020-03-17                202012
# 1         NaN              12  2020-03-17                202012
# 2  Rio Branco         1200401  2020-03-18                202012
# 3         NaN              12  2020-03-18                202012
# 4  Rio Branco         1200401  2020-03-19                202012
# 5         NaN              12  2020-03-19                202012
# 6  Rio Branco         1200401  2020-03-20                202012
# 7         NaN              12  2020-03-20                202012
# 8  Rio Branco         1200401  2020-03-21                202012
# 9         NaN              12  2020-03-21                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0                413418                     407319    False        False
# 1                894470                     881935    False        False
# ...

# %%
df.dropna(inplace=True)

# %%
df['city'].unique()
# Out:
# array(['Rio Branco', 'AcrelÃ¢ndia', 'Porto Acre', 'PlÃ¡cido de Castro',
#        'Bujari', 'Cruzeiro do Sul', 'Senador Guiomard', 'MÃ¢ncio Lima',
#        'Xapuri', 'Assis Brasil', 'FeijÃ³', 'TarauacÃ¡', 'Sena Madureira',
#        'EpitaciolÃ¢ndia', 'Capixaba', 'Santa Rosa do Purus', 'BrasilÃ©ia',
#        'Marechal Thaumaturgo', 'Rodrigues Alves', 'Manoel Urbano',
#        'Porto Walter', 'JordÃ£o'], dtype=object)

# %%
df['city'].replace({'AcrelÃ¢ndia' : 'Acrelândia', 'PlÃ¡cido de Castro' : 'Plácido de Castro', 'MÃ¢ncio Lima' : 'Mâncio Lima', 'FeijÃ³' : 'Feijó', 'TarauacÃ¡' : 'Tarauacá', 'EpitaciolÃ¢ndia' : 'Epitaciolândia', 'BrasilÃ©ia' : 'Brasiléia', 'JordÃ£o' : 'Jordão'}, inplace=True)

# %%
df['city'].unique()
# Out:
# array(['Rio Branco', 'Acrelândia', 'Porto Acre', 'Plácido de Castro',
#        'Bujari', 'Cruzeiro do Sul', 'Senador Guiomard', 'Mâncio Lima',
#        'Xapuri', 'Assis Brasil', 'Feijó', 'Tarauacá', 'Sena Madureira',
#        'Epitaciolândia', 'Capixaba', 'Santa Rosa do Purus', 'Brasiléia',
#        'Marechal Thaumaturgo', 'Rodrigues Alves', 'Manoel Urbano',
#        'Porto Walter', 'Jordão'], dtype=object)

# %%
df['ano'] = df["date"].str[:4].astype(object)
df['mes'] = df["date"].str[5:7].astype(object)

# %%
df['mes'].replace({'03':'Março', '04':'Abril', '05':'Maio', '06':'Junho'}, inplace=True)

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco         1200401  2020-03-17                202012
# 2  Rio Branco         1200401  2020-03-18                202012
# 4  Rio Branco         1200401  2020-03-19                202012
# 6  Rio Branco         1200401  2020-03-20                202012
# 8  Rio Branco         1200401  2020-03-21                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0                413418                     407319    False        False
# 2                413418                     407319    False        False
# 4                413418                     407319    False        False
# 6                413418                     407319    False        False
# 8                413418                     407319    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df1 = pd.read_csv('transito_dados.csv')

# %%
df1.head()
# Out:
#                         _id  \
# 0  6407641b305a576376e6f33c
# 1  6407641b305a576376e6f33d
# 2  6407641b305a576376e6f33e
# 3  6407641b305a576376e6f33f
# 4  6407641b305a576376e6f340
#
#                                         amparo_legal   ano  \
# 0  Lei 9503/97 Lei 10561/02 Res. CONTRAN nº 210/0...  2021
# 1  Lei 9503/97 Lei 10561/02 Res. CONTRAN nº 210/0...  2021
# 2  Lei 9503/97 Lei 10561/02 Res. CONTRAN nº 210/0...  2021
# 3  Lei 9503/97 Lei 10561/02 Res. CONTRAN nº 210/0...  2021
# 4  Lei 9503/97 Lei 10561/02 Res. CONTRAN nº 210/0...  2021
#
#                                   descricao_infracao  \
# 0  Transitar com o veículo excedendo a CMT em até...
# 1  Transitar com o veículo excedendo a CMT acima ...
# 2  Transitar com o veículo excedendo a CMT acima ...
# 3  Transitar com o veículo excedendo a CMT entre ...
# 4  Transitar com o veículo excedendo a CMT acima ...
#
#                      escopo_autuacao      mes  quantidade_autos  uf
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 970 non-null    object
#  1   amparo_legal        959 non-null    object
#  2   ano                 970 non-null    int64
#  3   descricao_infracao  970 non-null    object
#  4   escopo_autuacao     970 non-null    object
#  5   mes                 970 non-null    object
#  6   quantidade_autos    970 non-null    int64
#  7   uf                  970 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 60.8+ KB

# %%
df3 =  pd.concat([df, df1])

# %%
df3.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17              202012.0
# 2  Rio Branco       1200401.0  2020-03-18              202012.0
# 4  Rio Branco       1200401.0  2020-03-19              202012.0
# 6  Rio Branco       1200401.0  2020-03-20              202012.0
# 8  Rio Branco       1200401.0  2020-03-21              202012.0
#
#    estimated_population  estimated_population_2019 is_last is_repeated  \
# 0              413418.0                   407319.0   False       False
# 2              413418.0                   407319.0   False       False
# 4              413418.0                   407319.0   False       False
# 6              413418.0                   407319.0   False       False
# 8              413418.0                   407319.0   False       False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df3.fillna (0, inplace=True)

# %%
df3.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17              202012.0
# 2  Rio Branco       1200401.0  2020-03-18              202012.0
# 4  Rio Branco       1200401.0  2020-03-19              202012.0
# 6  Rio Branco       1200401.0  2020-03-20              202012.0
# 8  Rio Branco       1200401.0  2020-03-21              202012.0
#
#    estimated_population  estimated_population_2019 is_last is_repeated  \
# 0              413418.0                   407319.0   False       False
# 2              413418.0                   407319.0   False       False
# 4              413418.0                   407319.0   False       False
# 6              413418.0                   407319.0   False       False
# 8              413418.0                   407319.0   False       False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df3.to_csv('dados_finais.csv', index=0)
